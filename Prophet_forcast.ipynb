# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from fbprophet import Prophet

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
Covid_Data = pd.read_csv("/content/drive/MyDrive/Software Project/1.csv")

# %%
Covid_Data["state"].unique()
# Out:
# array(['IL', 'NC', 'ND', 'WI', 'VI', 'DE', 'MT', 'MI', 'ME', 'NH', 'CT',
#        'VT', 'GU', 'SC', 'FSM', 'WY', 'KY', 'DC', 'LA', 'VA', 'UT', 'PR',
#        'FL', 'KS', 'GA', 'MP', 'CO', 'OK', 'NYC', 'NY', 'WV', 'AK', 'MA',
#        'AR', 'AS', 'TX', 'HI', 'PW', 'NM', 'OH', 'RMI', 'IA', 'SD', 'TN',
#        'PA', 'MS', 'MD', 'AL', 'ID', 'MO', 'IN', 'WA', 'CA', 'NE', 'NV',
#        'OR', 'MN', 'RI', 'NJ', 'AZ'], dtype=object)

# %%
state_dict = {"Illionois":"IL", "North Carolina":"NC", "North Dakota":"ND", "Wisconsin ":"WI", "Virgin Islands":"VI","Delaware":"DE", "Montana": "MT","Michigan":"MI", "Maine":"ME", "New Hampshire":"NH", "Connecticut":"CT",
"Vermont":"VT", "Guam":"GU","South Carolina":"SC", "Micronesia":"FSM", "Wyoming": "WY", "Kentucky":"KY","Washington DC":"DC","Louisiana":"LA",
"Virginia":"VA", "Utah":"UT","Puerto Rico":"PR", "Florida":"FL","Kansas": "KS", "Georgia": "GA", "Northern Mariana Islands":"MP", "Colorado":"CO","Oklahoma":"OK","New York City":"NYC","New York":"NY", "West Virginia":"WV", "Alaska":"AK",
"Massachusetts":"MA", "Arkansas":"AR", "American Samoa" : "AS", "Texas":"TX", "Hawaii":"HI", "Palau":"PW", "New Mexico":"NM", "Ohio":"OH", "Marshall Islands":"RMI", "Iowa":"IA", "South Dakota": "SD","Tennessee":"TN", "Pennsylvania":"PA", "Mississippi":"MS","Maryland":"MD", "Alabama":"AL", "Idaho":"ID", "Missouri":"MO", "Indiana":"IN",
"Washington":"WA","California":"CA", "Nebraska":"NE", "Nevada":"NV", "Oregon":"OR", "Minnesota":"MN", "Rode Island":"RI", "New Jersey":"NJ", "Arizona":"AZ"}

# %%
def state_df(code):
  df = Covid_Data.loc[Covid_Data["state"]==code]
  df_prophet = pd.DataFrame()
  df_prophet["ds"] = df["submission_date"]
  df_prophet["y"] = df["new_case"]
  df_prophet.reset_index()
  return df_prophet

# %%
def predict_state():
  state = input("Enter your state ")
  code = ""
  for i in state_dict:
    if str(state) == i:
      code = state_dict[i]
  x_df = state_df(code)
  m = Prophet(daily_seasonality=True)
  m.fit(x_df)
  future = m.make_future_dataframe(periods=365)
  forecast = m.predict(future)
  figure = m.plot(forecast, xlabel='Date', ylabel = 'new_cases')

# %%
predict_state()
# Out:
# Enter your stateOhio

# %%
#MA
MA = Covid_Data.loc[Covid_Data["state"]=="MA"]
MA_prophet = pd.DataFrame()
MA_prophet["ds"] = MA["submission_date"]
MA_prophet["y"] = MA["new_case"]
MA_prophet.reset_index()
m = Prophet(daily_seasonality=True)
m.fit(MA_prophet)
future = m.make_future_dataframe(periods=365)
forecast = m.predict(future)
figure = m.plot(forecast, xlabel='Date', ylabel = 'new_cases')

# %%
#ILlinois
IL = Covid_Data.loc[Covid_Data["state"]=="IL"]
IL_prophet = pd.DataFrame()
IL_prophet["ds"] = IL["submission_date"]
IL_prophet["y"] = IL["new_case"]
IL_prophet.reset_index()
m = Prophet(daily_seasonality=True)
m.fit(IL_prophet)
future = m.make_future_dataframe(periods=365)
forecast = m.predict(future)
figure = m.plot(forecast, xlabel='Date', ylabel = 'new_cases')

# %%
def forcast_covide(state):
  x = Covid_Data.loc[Covid_Data["state"]==str(state)]
  x_prophet = pd.DataFrame()
  x_prophet["ds"] = x["submission_date"]
  x_prophet["y"] = x["new_case"]
  x_prophet.reset_index()
  m = Prophet(daily_seasonality=True)
  m.fit(x_prophet)
  future = m.make_future_dataframe(periods=365)
  forecast = m.predict(future)
  figure = m.plot(forecast, xlabel='Date', ylabel = 'new_cases')

# %%
#Wisconsin
WI = Covid_Data.loc[Covid_Data["state"]=="WI"]
WI_prophet = pd.DataFrame()
WI_prophet["ds"] = WI["submission_date"]
WI_prophet["y"] = WI["new_case"]
WI_prophet.reset_index()
m = Prophet(daily_seasonality=True)
m.fit(WI_prophet)
future = m.make_future_dataframe(periods=365)
forecast = m.predict(future)
figure = m.plot(forecast, xlabel='Date', ylabel = 'new_cases')

# %%
#NorthCarolina
NC = Covid_Data.loc[Covid_Data["state"]=="NC"]
NC_prophet = pd.DataFrame()
NC_prophet["ds"] = NC["submission_date"]
NC_prophet["y"] = NC["new_case"]
NC_prophet.reset_index()
m = Prophet(daily_seasonality=True)
m.fit(NC_prophet)
future = m.make_future_dataframe(periods=365)
forecast = m.predict(future)
figure = m.plot(forecast, xlabel='Date', ylabel = 'new_cases')

# %%
#DC
DC = Covid_Data.loc[Covid_Data["state"]=="DC"]
DC_prophet = pd.DataFrame()
DC_prophet["ds"] = DC["submission_date"]
DC_prophet["y"] = DC["new_case"]
DC_prophet.reset_index()
m = Prophet(daily_seasonality=True)
m.fit(DC_prophet)
future = m.make_future_dataframe(periods=365)
forecast = m.predict(future)
figure = m.plot(forecast, xlabel='Date', ylabel = 'new_cases')

# %%
#Oregon
OR = Covid_Data.loc[Covid_Data["state"]=="OR"]
OR_prophet = pd.DataFrame()
OR_prophet["ds"] = OR["submission_date"]
OR_prophet["y"] = OR["new_case"]
OR_prophet.reset_index()
m = Prophet(daily_seasonality=True)
m.fit(OR_prophet)
future = m.make_future_dataframe(periods=365)
forecast = m.predict(future)
figure = m.plot(forecast, xlabel='Date', ylabel = 'new_cases')

# %%
Covid
